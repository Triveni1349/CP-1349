# %% [markdown]
# <a href="https://colab.research.google.com/github/Triveni1349/CP-1349/blob/main/ASSIGN_3(MONDAY).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import bisect

def subset_sum_mitm(arr, target):
    n = len(arr)
    mid = n // 2

    left = arr[:mid]
    right = arr[mid:]

    sum_left = []
    sum_right = []

    # Generate all subset sums of left half
    for mask in range(1 << len(left)):
        s = 0
        for i in range(len(left)):
            if mask & (1 << i):
                s += left[i]
        sum_left.append(s)

    # Generate all subset sums of right half
    for mask in range(1 << len(right)):
        s = 0
        for i in range(len(right)):
            if mask & (1 << i):
                s += right[i]
        sum_right.append(s)

    # Sort right half sums for binary search
    sum_right.sort()

    # Check for target sum
    for s in sum_left:
        need = target - s
        idx = bisect.bisect_left(sum_right, need)
        if idx < len(sum_right) and sum_right[idx] == need:
            return True

    return False


# Main Driver Code
t = int(input())

for _ in range(t):
    n, S = map(int, input().split())
    arr = list(map(int, input().split()))

    if subset_sum_mitm(arr, S):
        print("YES")
    else:
        print("NO")
# Out:
# 2
# 4 9
# 3 1  7
# NO
# 5 10
# 2 4 6 8 1
# YES
